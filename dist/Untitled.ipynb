# %%
import pandas as pd

# %%
df = pd.read_csv('./data.csv')

# %%
df.set_index('Index')
# Out:
#                                               Activities  \
# Index
# 17     Assess and fill capacity gaps in relevant gove...
# 34     Assess and fill capacity gaps in relevant gove...
# 50     Assess and fill capacity gaps in relevant gove...
# 67     Assess and fill capacity gaps in relevant gove...
# 83     Assess and fill capacity gaps in relevant gove...
# ...                                                  ...
# 1      Undertake vaccination campaigns.\n\nImprove di...
# 53     Undertake vaccination campaigns.\n\nImprove di...
# 70     Undertake vaccination campaigns.\n\nImprove di...
# 20     Undertake vaccination campaigns.\n\nImprove di...
# 36     Undertake vaccination campaigns.\n\nImprove di...
#
#                                    Guidance, Environment  \
# Index
# 17     P7. Provide technical assistance, capacity bui...
# 34     P7. Develop a natural resource management unit...
# 50     P7. Provide technical assistance, capacity bui...
# ...

# %%
stuff = df.to_dict('records')

# %%
gb.first()
# Out:
#                    Intervention  Guidance
# Context Objective
# 1       1                     2         3
#         2                     5         4
#         3                     9         8
#         4                    12        11
#         5                    17        15
# 2       1                     2        22
#         2                     5        23
#         3                     9        27
#         4                    12        30
#         5                    17        32
# 3       1                     2        38
#         2                     5        39
#         3                     9        43
#         4                    12        46
#         5                    17        48
# 4       1                     1        52
#         2                     5        55
#         3                     9        58
#         4                    12        61
#         5                    17        65
# 5       1                     1        69
# ...

# %%
from collections import defaultdict

results = defaultdict(lambda: defaultdict(dict))

for index, value in gb.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-104072bd8b4d> in <module>
#       3 results = defaultdict(lambda: defaultdict(dict))
#       4
# ----> 5 for index, value in gb.itertuples():
#       6     for i, key in enumerate(index):
#       7         if i == 0:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'itertuples'

# %%
stuff
# Out:
# [{'Index': 17,
#   'Activities': 'Assess and fill capacity gaps in relevant government ministries.\n\nDevelop early warning and decision support systems and tools.',
#   'Guidance, Environment': 'P7. Provide technical assistance, capacity building, and financial resources for monitoring, policy, and extension work, especially focusing on integrated land management planning in pastoral systems.\n\nP7. Provide relevant ministries (e.g., agriculture, livestock, water, environment, rural development, finance, energy) with capacity building on pastoralism and sustainable rangeland and pasture management.\n\nP7. Develop early warning and decision support systems and tools for sustainable rangeland and pasture management.',
# ...

# %%
Html_file= open("filename","w")
Html_file.write(html_str)
Html_file.close()

# %%
for i in stuff:
    Html_file= open("guidance/ah/" + "guidance_index_" + str(i['Index']) + '.html',"w")
    Html_file.write(
        "<div class='text-area'> <div class='activities-area'>" + i['Activities'] +
        "</div> <div class='guidance-area'>" + i['Guidance, Health'] + "</div> </div>")
    Html_file.close()
    
    Html_file= open("./guidance/e/" + "guidance_index_" + str(i['Index']) + '.html',"w")
    Html_file.write(
                "<div class='text-area'> <div class='activities-area'>" + i['Activities'] +
        "</div> <div class='guidance-area'>" + i['Guidance, Environment'] + "</div> </div>")
    Html_file.close()

# %%
stuff[20]['Activities']
# Out:
# 'Develop animal identification, traceability and performance recording.\n\nInclude livestock data in the agriculture census.\n\nDevelop a database on livestock production at the central level.'

# %%
stuff[20]
# Out:
# {'Index': 66,
#  'Activities': 'Develop animal identification, traceability and performance recording.\n\nInclude livestock data in the agriculture census.\n\nDevelop a database on livestock production at the central level.',
#  'Guidance, Environment': 'P7. Include data on environmental performance in livestock information systems (e.g., GHG emissions, manure management practices, water use, nutrient balances).\n\nP7. Include training and resources for the collection of census data that can enable environmental performance assessment.',
# ...
